# %%
import pandas as pd
import numpy
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
traffic_20 = gpd.read_file("NYSDOT_TDV_AADT_2020.gdb.zip")

# %%
traffic_20['Traffic_Station_Locations_COU'].unique()
# Out:
# array([113., 115.,  87.,  75.,  13.,  81.,   7.,   5.,  63., 103.,  57.,
#         67.,  29., 119.,  59.,  69.,  51.,  71.,   9., 111.,  21.,  77.,
#         61.,  65.,  55.,  47., 101.,  49.,  79.,  85.,  93.,  89.,   3.,
#        105.,  43., 109.,  37.,  11.,  19.,  91.,  15.,  95., 121., 107.,
#         33.,  83.,  27.,  45.,  97.,  23.,   1.,  25.,  31., 123.,  35.,
#        117.,  39.,  99.,  73.,  53.,  17.,  41.,  nan,   0.,   2.,  16.])

# %%
## New York County Code = 61
traffic_M20 = traffic_20[traffic_20.Traffic_Station_Locations_COU == 61.]
traffic_M20.head()
# Out:
#     Traffic_Station_Locations_Rte Traffic_Station_Locations_Signing  \
# 34                            278                                 1
# 229
# 262
# 363
# 417
#
#      Traffic_Station_Locations_Qlfr Traffic_Station_Locations_Rmp  \
# 34                              1.0
# 229                             1.0
# 262                             1.0
# 363                             1.0
# 417                             0.0                  0I09501N401B
#
#      Traffic_Station_Locations_DOT_ID  Traffic_Station_Locations_CO  \
# 34                           100236.0                           4.0
# 229                          256849.0                           1.0
# 262                          256962.0                           1.0
# 363                          256714.0                           1.0
# 417                          274040.0                           1.0
#
#      Traffic_Station_Locations_FG Traffic_Station_Locations_BegDesc  \
# ...

# %%
traffic_M20.plot(legend=True,figsize=(30, 12))
plt.xlim(580000, 595000)
plt.ylim(4.501e6,4.53e6)
plt.axis('off')
plt.show()

# %%
traffic_19 = gpd.read_file("NYSDOT_TDV_AADT_2019.gdb.zip")

# %%
traffic_M19 = traffic_19[traffic_19.CountyFIPS == '061']
traffic_M19.plot(legend=True,figsize=(30, 12))
plt.xlim(580000, 595000)
plt.ylim(4.501e6,4.53e6)
plt.axis('off')
plt.show()

# %%
traffic_19['CountyFIPS'].unique()
# Out:
# array(['005', None, '047', '059', '061', '081', '085', '103', '001',
#        '031', '039', '083', '091', '093', '113', '115', '035', '041',
#        '043', '053', '057', '065', '011', '023', '067', '075', '099',
#        '109', '037', '051', '055', '069', '073', '121', '117', '009',
#        '013', '029', '063', '003', '015', '101', '097', '019', '123',
#        '033', '045', '049', '089', '021', '027', '071', '079', '087',
#        '111', '119', '007', '017', '025', '077', '095', '105', '107'],
#       dtype=object)
